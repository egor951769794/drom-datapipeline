# %%
import psycopg2
import pandas as pd
from time import sleep
import matplotlib.pyplot as plt
from datetime import date
import numpy as np

import boto3

# %%
POSTGRES_CONFIG = {
    'host': 'localhost',
    'port': '5430',
    'dbname': 'dwh',
    'user': 'user',
    'password': 'pwd',
}

# %%
def connect_to_db():
    print("Creating PostgreSQL connection...")
    while True:
        print("Trying to connect...")
        try:
            conn = psycopg2.connect(**POSTGRES_CONFIG)
            cur = conn.cursor()
            cur.execute('''SELECT version()''')
            version = cur.fetchone()
            print(f"PostgreSQL connection created! Version: {version}")
            return conn, cur

        except Exception as e:
            print(f"db connection failed:\n{e}")
            print("Retry connection after 5 sec...")
            sleep(5)

# %%
conn, cur = connect_to_db()
# Out:
# Creating PostgreSQL connection...
# Trying to connect...
# PostgreSQL connection created! Version: ('PostgreSQL 15.15 on x86_64-pc-linux-musl, compiled by gcc (Alpine 15.2.0) 15.2.0, 64-bit',)

# %%
def select(cursor):
    query = """select * from bulls_fact bf
    inner join dim_car dc on dc.car_key = bf.car_key
    inner join dim_condition dcd on dcd.condition_key = bf.condition_key
    """
    cursor.execute(query)
    return cursor.fetchall()

# %%
print("Initializing S3 connection...")

ENDPOINT = "http://localhost:9000"
session = boto3.Session(
    aws_access_key_id="dev_admin",
    aws_secret_access_key="dev_password",
    region_name="ru-central1"
)

s3 = session.client(
    "s3",
    endpoint_url=ENDPOINT
)

print(f"S3 connection to MinIO established")
# Out:
# Initializing S3 connection...
# S3 connection to MinIO established

# %%
s3r = boto3.resource(
    's3',
    endpoint_url='http://localhost:9000',
    aws_access_key_id="dev_admin",
    aws_secret_access_key="dev_password",
    region_name="ru-central1"
)

# %%
bulls_bucket = s3r.Bucket('bulletins')
bull_keys = [key.key for key in bulls_bucket.objects.all()]

bull_keys
# Out:
# ['bulletin_004e58dd.json',
#  'bulletin_007d5847.json',
#  'bulletin_0081fb8c.json',
#  'bulletin_00a0befe.json',
#  'bulletin_00b05fed.json',
#  'bulletin_011709cd.json',
#  'bulletin_01ebb490.json',
#  'bulletin_023f744e.json',
#  'bulletin_025cf59a.json',
#  'bulletin_025ff508.json',
#  'bulletin_026de3fe.json',
#  'bulletin_027616e9.json',
#  'bulletin_02e9551c.json',
#  'bulletin_03d2fe9f.json',
#  'bulletin_04046b06.json',
#  'bulletin_040f0336.json',
#  'bulletin_043557bb.json',
#  'bulletin_0437de96.json',
#  'bulletin_04b08700.json',
#  'bulletin_04c73a52.json',
#  'bulletin_04d0eec8.json',
#  'bulletin_04dc3fa0.json',
#  'bulletin_0522b30e.json',
#  'bulletin_0527c8f6.json',
#  'bulletin_05a6dc28.json',
#  'bulletin_05eb64ac.json',
#  'bulletin_0661851d.json',
#  'bulletin_06a30b69.json',
#  'bulletin_06a92323.json',
#  'bulletin_06cc30b5.json',
#  'bulletin_06fae702.json',
#  'bulletin_06fdbfe1.json',
#  'bulletin_071b0f95.json',
#  'bulletin_0723d2bf.json',
# ...

# %%
bulls = []

for key in bull_keys:
    response = s3.get_object(Bucket='bulletins', Key=key)
    bulls.append(response['Body'].read().decode('utf-8'))

# %%
bulls[0]
# Out:
# '{"timeReceived": "2026-02-01 01:28:38.974983", "bullUrl": "https://auto.drom.ru/omsk/chevrolet/lacetti/439362132.html", "imageUrls": ["https://s11.auto.drom.ru/photo/v2/subzbsSjqAtNWr0iqehyUb7AkO0o4Z37E-pg3bKY1-F71utllNLBETVg5ea32WobmBz3Rau9HsjQuPqw/gen1200.jpg", "https://s11.auto.drom.ru/photo/v2/W9Y0V1--fUphwivnZSJqsDH6Pipt4QZSxuzsqnms5P_5nralvcnehNbkTKb9VY-HZ0BWx_PZ0Eb_iWr0/gen1200.jpg", "https://s11.auto.drom.ru/photo/v2/MfeIgqp4aU6MEi0vgxbgsOP3nF1BobYCHvs0leo2oAkz7XdyW30zqDPzznsdamg1c32EhzR-jjwFVYK3/gen1200.jpg", "https://s11.auto.drom.ru/photo/v2/NoFDoWDxHxhhBxI3erYCifc5wbQLyzSSK8UvQn3DrcSsE6f3I63hZH1Y1TW0rMgc8vaiCjOVZTims6yE/gen1200.jpg", "https://s11.auto.drom.ru/photo/v2/6uYVExtezIuDlgK6mDm9Qyvp3CGWp988fnoHsvj5sipchtJb5_hjZTH8U1mtpFtWrtvAHlWpT4jj24Rd/gen1200.jpg"], "manufacturer": "Chevrolet", "model": "Lacetti", "year": 2007, "config": null, "engineCapacity": 1.4, "enginePower": 95, "engineType": "бензин", "transmissionType": "механика", "wheelDrive": "передний", "mileage"
# ...

# %%
bulls_df = pd.DataFrame(bulls, 
    columns=["time_received", "bull_url", "image_urls", "manufacturer", "model", "year", "config", "engine_capacity", "engine_power", 
             "engine_type", "transmission_type", 
            ]
    )

# %%
bulls_df = bulls_df.drop(
        columns=["event_id", "time_received", "bull_id", "bull_hash", "car_key", "date_key", "condition_key",
            "car_key1", "condition_key1"])

# %%
bulls_df
# Out:
#       mileage  price_rub location  num_of_owners  num_of_previous_bulls  \
# 0    160000.0     260000     Омск            6.0                   11.0
# 1    288890.0     899000     Омск            5.0                    2.0
# 2    247000.0    1390000     Омск            4.0                    5.0
# 3    222000.0    1800000     Омск            3.0                    NaN
# 4    139000.0     283000     Омск            8.0                    9.0
# ..        ...        ...      ...            ...                    ...
# 986  378000.0     350000     Омск            NaN                    NaN
# 987  270000.0     450000     Омск            3.0                    3.0
# 988  190000.0    1450000     Омск            2.0                    3.0
# 989  144111.0     400000     Омск            3.0                    NaN
# 990  173000.0     540000     Омск            2.0                    3.0
#
#     manufacturer        model  year engine_capacity  engine_power  ...  \
# ...

# %%
bulls_df.isna().sum()
# Out:
# mileage                   29
# price_rub                  0
# location                   0
# num_of_owners            115
# num_of_previous_bulls    380
# manufacturer               0
# model                      0
# year                       0
# engine_capacity            5
# engine_power               6
# engine_type                2
# transmission_type         17
# wheel_drive                2
# steering                  17
# color                     16
# by_order                   0
# from_owner                 0
# is_new                     0
# no_mileage_in_russia       0
# is_broken                  0
# no_docs                    0
# passport_issues          104
# owned_by_company           0
# has_penalties              0
# dtype: int64

# %%
print(f"Data quality: {round(100 * (bulls_df.dropna().shape[0]) / bulls_df.shape[0], 3)}%")
print(f"Quality rows left {bulls_df.dropna().shape[0]}")
# Out:
# Data quality: 55.802%
# Quality rows left 553

# %%
bulls_df_no_prev_bulls = bulls_df.drop(columns=["num_of_previous_bulls"])
print(f"Data quality (no number_of_prev_bulls column): {round(100 * (bulls_df_no_prev_bulls.dropna().shape[0]) / bulls_df_no_prev_bulls.shape[0], 3)}%")
print(f"Quality rows left {bulls_df_no_prev_bulls.dropna().shape[0]}")
# Out:
# Data quality (no number_of_prev_bulls column): 80.626%
# Quality rows left 799

# %%
bulls_df.describe()
# Out:
#              mileage     price_rub  num_of_owners  num_of_previous_bulls  \
# count     962.000000  9.910000e+02     876.000000             611.000000
# mean   181951.355509  1.348879e+06       3.506849               4.813421
# std    106469.614785  1.745582e+06       2.194788               3.159874
# min        10.000000  4.700000e+04       1.000000               2.000000
# 25%    100000.000000  4.625000e+05       2.000000               2.000000
# 50%    183000.000000  8.950000e+05       3.000000               4.000000
# 75%    249617.250000  1.634500e+06       5.000000               6.000000
# max    828000.000000  2.400000e+07      15.000000              22.000000
#
#               year  engine_power
# count   991.000000    985.000000
# mean   2010.984864    141.675127
# std       7.711514     63.583151
# min    1981.000000     51.000000
# 25%    2006.000000    100.000000
# 50%    2011.000000    124.000000
# 75%    2017.000000    160.000000
# max    2026.000000    560.000000

# %%
bulls_df['car_age'] = date.today().year - bulls_df['year']

mileage_per_year = bulls_df['mileage'] / bulls_df['car_age']
avg_mileage_per_year = mileage_per_year.mean()

bulls_df['mileage'] = bulls_df['mileage'].fillna(avg_mileage_per_year)

bulls_df['num_of_owners'] = bulls_df['num_of_owners'].fillna(bulls_df['num_of_owners'].mean())
bulls_df['num_of_previous_bulls'] = bulls_df['num_of_previous_bulls'].fillna(bulls_df['num_of_previous_bulls'].mean())
bulls_df['engine_type'] = bulls_df['engine_type'].fillna(bulls_df['engine_type'].mode()[0])
bulls_df['transmission_type'] = bulls_df['transmission_type'].fillna(np.random.choice(['АКПП', 'механика']))
bulls_df['wheel_drive'] = bulls_df['wheel_drive'].fillna(bulls_df['wheel_drive'].mode()[0])
bulls_df['steering'] = bulls_df['steering'].fillna(bulls_df['steering'].mode()[0])
bulls_df['steering'] = bulls_df['steering'].fillna(bulls_df['steering'].mode()[0])
bulls_df['color'] = bulls_df['color'].fillna(bulls_df['color'].mode()[0])
bulls_df['passport_issues'] = bulls_df['passport_issues'].fillna(bulls_df['passport_issues'].mode()[0])

bulls_df = bulls_df.dropna()

# %%
bulls_df.isna().sum()
# Out:
# mileage                  0
# price_rub                0
# location                 0
# num_of_owners            0
# num_of_previous_bulls    0
# manufacturer             0
# model                    0
# year                     0
# engine_capacity          0
# engine_power             0
# engine_type              0
# transmission_type        0
# wheel_drive              0
# steering                 0
# color                    0
# by_order                 0
# from_owner               0
# is_new                   0
# no_mileage_in_russia     0
# is_broken                0
# no_docs                  0
# passport_issues          0
# owned_by_company         0
# has_penalties            0
# car_age                  0
# dtype: int64

# %%
bulls_df
# Out:
#       mileage  price_rub location  num_of_owners  num_of_previous_bulls  \
# 0    160000.0     260000     Омск       6.000000              11.000000
# 1    288890.0     899000     Омск       5.000000               2.000000
# 2    247000.0    1390000     Омск       4.000000               5.000000
# 3    222000.0    1800000     Омск       3.000000               4.813421
# 4    139000.0     283000     Омск       8.000000               9.000000
# ..        ...        ...      ...            ...                    ...
# 986  378000.0     350000     Омск       3.506849               4.813421
# 987  270000.0     450000     Омск       3.000000               3.000000
# 988  190000.0    1450000     Омск       2.000000               3.000000
# 989  144111.0     400000     Омск       3.000000               4.813421
# 990  173000.0     540000     Омск       2.000000               3.000000
#
#     manufacturer        model  year engine_capacity  engine_power  ...  \
# ...

# %%
y = bulls_df['price_rub']
X = bulls_df.drop(columns=['price_rub'])
print(X.shape)
# Out:
# (985, 24)

# %%
def train_test_split(x, y, test_size):
    indices = np.random.choice(x.index, size=int(x.shape[0] * test_size), replace=False)
    x_test = x.iloc[indices]
    y_test = y.iloc[indices]

    x_train = x.drop(x.index[indices])
    y_train = y.drop(y.index[indices])

    return x_test, y_test, x_train, y_train

# %%
X_test, y_test, X_train, y_train = train_test_split(X, y, 0.15)

print(X_test.shape, y_test.shape, X_train.shape, y_train.shape)
print(X.shape, y.shape)
# Out:
# (147, 24) (147,) (838, 24) (838,)
# (985, 24) (985,)

# %%
from catboost import CatBoostRegressor

category_names = ["location", "manufacturer", "model", "engine_type", "transmission_type", "wheel_drive", "steering", "color",
                 "by_order", "from_owner", "is_new", "no_mileage_in_russia", "is_broken", "no_docs", "passport_issues", "owned_by_company",
                  "has_penalties"
                 ]

# %%
model = CatBoostRegressor(
    cat_features=category_names,
    iterations=2000,
    learning_rate=0.1,
    depth=6,
    verbose=100
)

model.fit(X_train, y_train)
# Out:
# 0:	learn: 1466353.2068145	total: 30.9ms	remaining: 1m 1s
# 100:	learn: 314311.6925470	total: 3.59s	remaining: 1m 7s
# 200:	learn: 215683.6649026	total: 7.14s	remaining: 1m 3s
# 300:	learn: 170987.4401471	total: 10.7s	remaining: 1m
# 400:	learn: 141146.6600898	total: 14.2s	remaining: 56.7s
# 500:	learn: 118503.2767734	total: 17.7s	remaining: 53s
# 600:	learn: 102487.0999222	total: 21.3s	remaining: 49.6s
# 700:	learn: 89298.1422898	total: 24.8s	remaining: 46s
# 800:	learn: 76862.7240559	total: 28.4s	remaining: 42.5s
# 900:	learn: 67562.9733268	total: 32.1s	remaining: 39.1s
# 1000:	learn: 60930.6329463	total: 35.6s	remaining: 35.5s
# 1100:	learn: 54960.2828918	total: 39.1s	remaining: 31.9s
# 1200:	learn: 49773.5018906	total: 42.7s	remaining: 28.4s
# 1300:	learn: 45109.3500687	total: 46.2s	remaining: 24.8s
# 1400:	learn: 40697.0471554	total: 49.8s	remaining: 21.3s
# 1500:	learn: 36562.0456570	total: 53.5s	remaining: 17.8s
# 1600:	learn: 33807.9364473	total: 57s	remaining: 14.2s
# ...

# %%
predict_prices = []
true_prices = []

X_test_ = X_test.reset_index(drop=True)
y_test_ = y_test.reset_index(drop=True)

for i in range(40, 80):
    true_prices.append(y_test_[i])
    predict_prices.append(model.predict(X_test_.loc[i]))

# %%
plt.scatter(range(40), true_prices)
plt.scatter(range(40), predict_prices)
plt.ylim(-500000, 3000000)
# Out:
# (-500000.0, 3000000.0)

# %%
print(model.predict(X_test_.loc[49]))
print(y_test_.loc[49])
X_test_.loc[49]
# Out:
# 75246.80116141471
# 220000
# mileage                  150000.0
# location                     Омск
# num_of_owners                 2.0
# num_of_previous_bulls    4.813421
# manufacturer                 Лада
# model                        2107
# year                         2005
# engine_capacity               1.6
# engine_power                 74.0
# engine_type                бензин
# transmission_type        механика
# wheel_drive                задний
# steering                    левый
# color                    бордовый
# by_order                    False
# from_owner                  False
# is_new                      False
# no_mileage_in_russia        False
# is_broken                   False
# no_docs                     False
# passport_issues             False
# owned_by_company            False
# has_penalties               False
# car_age                        21
# Name: 49, dtype: object

# %%
model.predict([
    260000, 'Омск', 5, 3, 'Nissan', 'Almera', 2005, 1.8, 116, 'бензин', 'механика', 'передний', 'левый', 'черный', False, True, False,
    False, False, False, False, False, False, 21
])
# Out:
# np.float64(424032.45472866565)

# %%
importance_df = pd.DataFrame({
    'feature_name': X_test.columns,
    'importance': model.feature_importances_
}).sort_values(by='importance', ascending=False)

importance_df
# Out:
#              feature_name  importance
# 8            engine_power   20.703886
# 6                    year   14.995483
# 23                car_age   14.953568
# 7         engine_capacity   12.741678
# 9             engine_type    9.986061
# 4            manufacturer    5.878881
# 0                 mileage    5.779631
# 10      transmission_type    5.279940
# 11            wheel_drive    4.829173
# 13                  color    1.388261
# 2           num_of_owners    1.249830
# 5                   model    1.186050
# 3   num_of_previous_bulls    0.412658
# 1                location    0.304712
# 12               steering    0.090969
# 18              is_broken    0.076357
# 16                 is_new    0.039453
# 19                no_docs    0.029296
# 15             from_owner    0.025710
# 21       owned_by_company    0.020019
# 17   no_mileage_in_russia    0.017480
# 20        passport_issues    0.010127
# 14               by_order    0.000639
# 22          has_penalties    0.000137
